# %%
#!conda install -c anaconda beautifulsoup4 --yes
#!conda install -c conda-forge geopy --yes 
import requests
import pandas as pd
from bs4 import BeautifulSoup
import numpy as np
import folium
from geopy.geocoders import Nominatim
import json

# %%
CLIENT_ID = 'E3D0QOUTQHHB5IQV0U5UK5U1RSYLGKURHHL4ER5YAOD0J0ND' # your Foursquare ID
CLIENT_SECRET = 'QY2SK34DH5S3EWEWV1XCLXPHWW5ZTIY3LAH2FXWWPJQ0D0H1' # your Foursquare Secret
VERSION = '20190605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: E3D0QOUTQHHB5IQV0U5UK5U1RSYLGKURHHL4ER5YAOD0J0ND
# CLIENT_SECRET:QY2SK34DH5S3EWEWV1XCLXPHWW5ZTIY3LAH2FXWWPJQ0D0H1

# %%
radius = 200
lat = 28.5245
long = 77.1855
LIMIT=100
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            long, 
            radius, 
            LIMIT)
res=requests.get(url).json()

# %%
res['response']['groups'][0]['items'][0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4ba47c9bf964a520fe9f38e3',
#   'name': 'Qutub Minar | क़ुतुब मीनार (Qutub Minar)',
#   'location': {'address': 'Lado Sarai',
#    'lat': 28.525265048263833,
#    'lng': 77.18659304744011,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 28.525265048263833,
#      'lng': 77.18659304744011}],
#    'distance': 136,
#    'postalCode': '110030',
#    'cc': 'IN',
#    'city': 'New Delhi',
#    'state': 'Delhi',
#    'country': 'India',
#    'formattedAddress': ['Lado Sarai', 'New Delhi 110030', 'Delhi', 'India']},
#   'categories': [{'id': '4bf58dd8d48988d12d941735',
#     'name': 'Monument / Landmark',
#     'pluralName': 'Monuments / Landmarks',
#     'shortName': 'Landmark',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#      'suffix': '.png'},
# ...

# %%
search_query = 'Qutub Minar'
url2 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, lat, long, VERSION, search_query, radius, LIMIT)
res2 = requests.get(url2).json()

# %%
res2["response"]['venues'][0]
# Out:
# {'id': '4ba47c9bf964a520fe9f38e3',
#  'name': 'Qutub Minar | क़ुतुब मीनार (Qutub Minar)',
#  'location': {'address': 'Lado Sarai',
#   'lat': 28.525265048263833,
#   'lng': 77.18659304744011,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 28.525265048263833,
#     'lng': 77.18659304744011}],
#   'distance': 136,
#   'postalCode': '110030',
#   'cc': 'IN',
#   'city': 'New Delhi',
#   'state': 'Delhi',
#   'country': 'India',
#   'formattedAddress': ['Lado Sarai', 'New Delhi 110030', 'Delhi', 'India']},
#  'categories': [{'id': '4bf58dd8d48988d12d941735',
#    'name': 'Monument / Landmark',
#    'pluralName': 'Monuments / Landmarks',
#    'shortName': 'Landmark',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#     'suffix': '.png'},
#    'primary': True}],
#  'referralId': 'v-1589111689',
#  'hasPerk': False}

# %%
venue_id = '4ba47c9bf964a520fe9f38e3'
url3 = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
res3 = requests.get(url3).json()

# %%
res3["response"]["venue"]
#tip count
#likes count
#rating
#photos count
# Out:
# {'id': '4ba47c9bf964a520fe9f38e3',
#  'name': 'Qutub Minar | क़ुतुब मीनार (Qutub Minar)',
#  'contact': {},
#  'location': {'address': 'Lado Sarai',
#   'lat': 28.525265048263833,
#   'lng': 77.18659304744011,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 28.525265048263833,
#     'lng': 77.18659304744011}],
#   'postalCode': '110030',
#   'cc': 'IN',
#   'city': 'New Delhi',
#   'state': 'Delhi',
#   'country': 'India',
#   'formattedAddress': ['Lado Sarai', 'New Delhi 110030', 'Delhi', 'India']},
#  'canonicalUrl': 'https://foursquare.com/v/qutub-minar--%E0%A4%95%E0%A4%A4%E0%A4%AC-%E0%A4%AE%E0%A4%A8%E0%A4%B0/4ba47c9bf964a520fe9f38e3',
#  'categories': [{'id': '4bf58dd8d48988d12d941735',
#    'name': 'Monument / Landmark',
#    'pluralName': 'Monuments / Landmarks',
#    'shortName': 'Landmark',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#     'suffix': '.png'},
#    'primary': True},
# ...

# %%
mmi_client_id='FlqWid5iTIaS_bAT6Jz9npxt2TSexJueQYISt_Ff01UGDdfEpbWB_VASXjhELcsBxj6Dcrugqs8='
mmi_client_secret='OHg66Y0l5BRU9wYngm8c3PXyVfkF3B2PZRLpCnuNdcH4vx-tNYqgWOe_y4AbdNSjSXyQ4FfdzSkgkEjjo8H1uA=='
mmi_rest_key='u3scdp3wbk23jxpn8xip1xodqnws3fe9'

# %%
_headers={'Content-Type':"application/x-www-form-urlencoded"}

_data={'grant_type':'client_credentials',
       'client_id':mmi_client_id,
       'client_secret':mmi_client_secret}

url4_1='https://outpost.mapmyindia.com/api/security/oauth/token'

res4_1=requests.post(url4_1,headers=_headers,data=_data).json()

access_token=res4_1['access_token']
token_type=res4_1['token_type']
_headers2={'Authorization':'{} {}'.format(token_type,access_token)}

# %%
url4_2 = 'https://atlas.mapmyindia.com/api/places/textsearch/json?query={}&latitude={}&longitude={}'.format(search_query,lat,long)
res4_2=requests.get(url4,headers=_headers2).json()
res4_2
# Out:
# {'suggestedLocations': [{'type': 'POI',
#    'typeX': 7,
#    'placeAddress': 'Mehrauli, New Delhi, Delhi, 110030',
#    'latitude': 28.524454,
#    'longitude': 77.1854700000001,
#    'eLoc': 'N6OQYB',
#    'entryLatitude': 28.5254890000001,
#    'entryLongitude': 77.187329,
#    'placeName': 'Qutub Minar',
#    'alternateName': 'Qutab Minar,Qutb Minar',
#    'keywords': ['HISMON'],
#    'p': 3,
#    'distance': 0.0,
#    'orderIndex': 1,
#    'score': 280932504922.45996,
#    'suggester': 'placeName',
#    'addressTokens': {},
#    'richInfo': {}},
#   {'type': 'POI',
#    'typeX': 7,
#    'placeAddress': 'Lado Sarai, New Delhi, Delhi, 110030',
#    'latitude': 28.512864,
#    'longitude': 77.186068,
#    'eLoc': '5BEDDA',
#    'entryLatitude': 28.5129370000001,
#    'entryLongitude': 77.1858710000001,
#    'placeName': 'Qutab Minar Metro Station',
#    'alternateName': 'Qutub Minar Metro Station,Qutb Minar Metro Station',
#    'keywords': ['TRNMET'],
#    'p': 5308,
# ...

# %%
eLOC='N6OQYB'
url5 = 'https://apis.mapmyindia.com/advancedmaps/v1/{}/place_detail?place_id={}'.format(mmi_rest_key,eLOC)
res5=requests.get(url5).json()

# %%
res5
# Out:
# {'responseCode': 200,
#  'version': '221.19',
#  'results': [{'houseNumber': '',
#    'houseName': '',
#    'poi': 'Qutub Minar',
#    'street': 'Baba Sri Chand Marg',
#    'subSubLocality': '',
#    'subLocality': 'Seth Sarai',
#    'locality': 'Mehrauli',
#    'village': '',
#    'district': 'South District',
#    'subDistrict': 'Hauz Khas',
#    'city': 'New Delhi',
#    'state': 'Delhi',
#    'pincode': '110030',
#    'longitude': '77.1854700000001',
#    'latitude': '28.524454',
#    'type': 'POI',
#    'place_id': 'N6OQYB'}]}

# %%
google_key='AIzaSyCFOONmzl3OoyRiZgtwknhx1pr1mica9mM'

# %%
fields='fields=address_component,adr_address,formatted_address,name,place_id,type,vicinity'
url6='https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input={}&inputtype=textquery&{}&key={}&locationbias=point:{},{}'.format(search_query,fields,google_key,lat,long)
res6=requests.get(url6).json()

# %%
res6
# Out:
# {'candidates': [{'name': 'Qutub Minar',
#    'place_id': 'ChIJT5uBZwYeDTkRuJ11YPGVSYM',
#    'rating': 4.5,
#    'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 93297}],
#  'status': 'OK'}

# %%
place_id = 'ChIJT5uBZwYeDTkRuJ11YPGVSYM'
fields2='address_component,adr_address,business_status,formatted_address,geometry,name,place_id,type,utc_offset,vicinity,price_level,rating,user_ratings_total'
url7='https://maps.googleapis.com/maps/api/place/details/json?key={}&place_id={}&{}'.format(google_key,place_id,fields2)
res7=requests.get(url7).json()

# %%
res7
# Out:
# {'html_attributions': [],
#  'result': {'address_components': [{'long_name': 'Mehrauli',
#     'short_name': 'Mehrauli',
#     'types': ['sublocality_level_1', 'sublocality', 'political']},
#    {'long_name': 'Seth Sarai',
#     'short_name': 'Seth Sarai',
#     'types': ['sublocality_level_2', 'sublocality', 'political']},
#    {'long_name': 'New Delhi',
#     'short_name': 'New Delhi',
#     'types': ['locality', 'political']},
#    {'long_name': 'South Delhi',
#     'short_name': 'South Delhi',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'Delhi',
#     'short_name': 'DL',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'India',
#     'short_name': 'IN',
#     'types': ['country', 'political']},
#    {'long_name': '110030', 'short_name': '110030', 'types': ['postal_code']}],
# ...

# %%
df=pd.DataFrame()
df=df.append([['Marine Drive',18.9431,72.8272,'Maharashtra','Mumbai',400002,'','',np.nan,np.nan,np.nan,np.nan,np.nan]])
df=df.append([['Baga Beach',15.5553,73.7517,'Goa','Bardez',403516,'','',np.nan,np.nan,np.nan,np.nan,np.nan]])
df=df.append([['Qutub Minar',28.5245,77.1855,'New Delhi','Delhi',110030,'','',np.nan,np.nan,np.nan,np.nan,np.nan]])
df=df.append([['Golden Temple',31.62,74.8765,'Amritsar','Punjab',143006,'','',np.nan,np.nan,np.nan,np.nan,np.nan]])
df=df.append([['Mysore Palace',12.3051,76.6551,'Mysore','Karnataka',570004,'','',np.nan,np.nan,np.nan,np.nan,np.nan]])
df.columns=['Name','Latitude','Longitude','State','City','Postal','District','Category','Rating','Visit Count','State Cases','City Cases','District Cases']
df=df.reset_index().drop(['index'],axis=1)

# %%
df
# Out:
#             Name  Latitude  Longitude        State       City  Postal  \
# 0   Marine Drive   18.9431    72.8272  Maharashtra     Mumbai  400002
# 1     Baga Beach   15.5553    73.7517          Goa     Bardez  403516
# 2    Qutub Minar   28.5245    77.1855    New Delhi      Delhi  110030
# 3  Golden Temple   31.6200    74.8765     Amritsar     Punjab  143006
# 4  Mysore Palace   12.3051    76.6551       Mysore  Karnataka  570004
#
#   District Category  Rating  Visit Count  State Cases  City Cases  \
# 0                       NaN          NaN          NaN         NaN
# 1                       NaN          NaN          NaN         NaN
# 2                       NaN          NaN          NaN         NaN
# 3                       NaN          NaN          NaN         NaN
# 4                       NaN          NaN          NaN         NaN
#
#    District Cases
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
